# %% [markdown]
# # Lab work tasks:
# 1.	Student Record System:
# •	You are making a small program for your university to store student details.
# •	Define a function that takes a student’s name and registration number and prints them.
# •	Try calling this function using:
# o	Positional arguments.
# o	Keyword arguments.
# o	Default arguments
# •	Test what happens if you pass fewer arguments than required.
# •	Check if Python allows a positional argument after a keyword argument.

# %%
# Function definition
def student_record(name, reg_no):
    print(f"Name: {name}, Registration No: {reg_no}")

# %%
# Positional arguments
student_record('ausd',2344)
# Out:
# Name: ausd, Registration No: 2344

# %%
# Positional arguments
student_record("Ali", "EE123")
# Out:
# Name: Ali, Registration No: EE123

# %%
# Keyword arguments
student_record(name="Saboor", reg_no="24jzele0573")
# Out:
# Name: Saboor, Registration No: 24jzele0573

# %%
# Default arguments
student_record()
# Out:
# Name: Unknown, Registration No: 0000

# %%
# Fewer arguments than required
student_record("ahmad")
# Out:
# Name: ahmad, Registration No: 0000

# %% [markdown]
# # 1.	Student Record System:
# •	You are making a small program for your university to store student details.
# •	Define a function that takes a student’s name and registration number and prints them.
# •	Try calling this function using:
# o	Positional arguments.
# o	Keyword arguments.
# o	Default arguments
# •	Test what happens if you pass fewer arguments than required.
# •	Check if Python allows a positional argument after a keyword argument.

# %%
# Function definition
def ohms_law(I=1, R=1):
    return I * R

# %%
# Positional arguments
print("Voltage:", ohms_law(5, 10))
# Out:
# Voltage: 50

# %%
# Keyword arguments
print("Voltage:", ohms_law(I=2, R=20))
# Out:
# Voltage: 40

# %%
# Default arguments
print("Voltage:", ohms_law())
# Out:
# Voltage: 1

# %%
# Mixing argument styles
print("Voltage:", ohms_law(3, R=15))
# Out:
# Voltage: 45

# %% [markdown]
# # 3.	Solar Battery Charging:
# A solar inverter monitors the battery’s state of charge (SOC).
# •	Write a function charge_from_solar(SOC) that:
# o	Prints "Charging" if SOC < 20%.
# o	Prints "Battery full, no action" if SOC > 90%.
# o	Prints "Battery charging, SOC = ---%" otherwise.
# •	Add docstrings and function annotations.
# •	Print the function’s docstring to check.

# %%
def charge_from_solar(SOC: int) -> None:
    """
    Monitors battery state of charge (SOC) and prints charging status.
    SOC < 20%  -> "Charging"
    SOC > 90%  -> "Battery full, no action"
    Otherwise  -> "Battery charging, SOC = ---%"
    """
    if SOC < 20:
        print("Charging")
    elif SOC > 90:
        print("Battery full, no action")
    else:
        print(f"Battery charging, SOC = {SOC}%")

# %%
# Test
charge_from_solar(10)
charge_from_solar(95)
charge_from_solar(50)

# %%
# Print docstring
print(charge_from_solar.__doc__)
# Out:
#     Monitors battery state of charge (SOC) and prints charging status.
#     SOC < 20%  -> "Charging"
#     SOC > 90%  -> "Battery full, no action"
#     Otherwise  -> "Battery charging, SOC = ---%"

# %% [markdown]
# # 4.	Resistance, Voltage, and Current Lists:
# You are building a program to analyze five resistor values in a circuit.
# •	Function 1: resistance():  return a list of 5 resistances.
# •	Function 2: voltage():  return voltages across each resistor.
# •	Function 3: current():  take both lists (Resistance & Voltage) and calculate currents.
# •	Display all lists nicely in the main program.
# •	Try two versions:
# o	Return as a tuple.
# o	Return as a dictionary with keys like "current_1".

# %%
def resistance() -> list[float]:
    return [10,20,30,40,50]

# %%
def voltage() -> list[float]:

    return [5,10,15,20,25]

# %%
def current(res: list[float], volt: list[float]) -> tuple:
    
    currents = tuple(v / r for v, r in zip(volt, res))
    return currents

# %%
if __name__ == "_main_":
    resistances = resistance()              
    voltages = voltage()                    
    currents = current(resistances ,voltages)

# %%
print("Resistances (Ohms):", resistances)
print("Voltages (Volts):  ", voltages)
print("Currents (Amps):", current)
# Out:
# Resistances (Ohms): [10, 20, 30, 40, 50]
# Voltages (Volts):   [100, 200, 150, 120, 250]
# Currents (Amps): <function current at 0x000001AE5BA4A5F0>
