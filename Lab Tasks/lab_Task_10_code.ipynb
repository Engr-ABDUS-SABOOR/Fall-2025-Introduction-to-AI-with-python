# %% [markdown]
# # Task 1: Filter Voltage Readings
# You have a list of voltage readings from a sensor:
# voltages = [224, 198, 231, 177, 205, 189, 240]
# Create a list comprehension to extract only the readings below 200 volts.

# %%
voltages = [224, 198, 231, 177, 205, 189, 240]

# Extract voltages below 200
low_voltages = [v for v in voltages if v < 200]

print("Voltage readings below 200V:", low_voltages)
# Out:
# Voltage readings below 200V: [198, 177, 189]

# %% [markdown]
# # Task 2: Convert Power Ratings to kW
# Given power values in watts:
# powers_w = [50, 120, 300, 750, 1500]
# Use a list comprehension to convert all values to kilowatts

# %%
powers_w = [50, 120, 300, 750, 1500]

# Convert watts to kilowatts
powers_kw = [p / 1000 for p in powers_w]

print("Power values in kW:", powers_kw)
# Out:
# Power values in kW: [0.05, 0.12, 0.3, 0.75, 1.5]

# %% [markdown]
# # Task 3: Square Only Even Resistances
# You measured resistance values:
# resistors = [10, 15, 22, 47, 50, 68]
# Create a list of squares of only the even resistor values.

# %%
resistors = [10, 15, 22, 47, 50, 68]

# Square only even resistance values
even_resistor_squares = [r**2 for r in resistors if r % 2 == 0]

print("Squares of even resistances:", even_resistor_squares)
# Out:
# Squares of even resistances: [100, 484, 2500, 4624]

# %% [markdown]
# # Task 4: Label Currents as “High” or “Low”
# Given:
# currents = [2.1, 0.5, 1.8, 3.0, 0.9]
# Use a list comprehension to return:
# "High" if current > 1.5 A else "Low".

# %%
currents = [2.1, 0.5, 1.8, 3.0, 0.9]

# Label currents as High or Low
current_labels = ["High" if c > 1.5 else "Low" for c in currents]

print("Current Labels:", current_labels)
# Out:
# Current Labels: ['High', 'Low', 'High', 'High', 'Low']

# %% [markdown]
# # Task 5: Extract Appliance Names Starting With ‘F’
# Given appliance names:
# appliances = ["Fan", "Fridge", "Light", "Freezer", "Pump"]
# Use a list comprehension to extract only names starting with “F”.

# %%
appliances = ["Fan", "Fridge", "Light", "Freezer", "Pump"]

# List comprehension to get names starting with 'F'
f_appliances = [a for a in appliances if a.startswith("F")]

print("Appliances starting with 'F':", f_appliances)
# Out:
# Appliances starting with 'F': ['Fan', 'Fridge', 'Freezer']

# %% [markdown]
# # Task 6: Generate First 10 Multiples of 50
# Use a list comprehension to generate:
# [50, 100, 150, ..., 500]
# No loops. Only list comprehension

# %%
# Generate first 10 multiples of 50
multiples_of_50 = [50 * i for i in range(1, 11)]

print("First 10 multiples of 50:", multiples_of_50)
# Out:
# First 10 multiples of 50: [50, 100, 150, 200, 250, 300, 350, 400, 450, 500]
